# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
# from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install -q keras

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2305
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2305 files belonging to 9 classes.
# Using 1844 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2305 files belonging to 9 classes.
# Using 461 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrap  (None, 178, 178, 32)      896
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 176, 176, 32)      9248
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 88, 88, 32)        0
#  apper)
#
#  module_wrapper_3 (ModuleWr  (None, 86, 86, 64)        18496
#  apper)
#
#  batch_normalization (Batch  (None, 86, 86, 64)        256
#  Normalization)
#
#  module_wrapper_4 (ModuleWr  (None, 43, 43, 64)        0
#  apper)
#
#  module_wrapper_5 (ModuleWr  (None, 41, 41, 128)       73856
#  apper)
#
#  batch_normalization_1 (Bat  (None, 41, 41, 128)       512
#  chNormalization)
#
#  module_wrapper_6 (ModuleWr  (None, 20, 20, 128)       0
#  apper)
#
#  module_wrapper_7 (ModuleWr  (None, 51200)             0
#  apper)
#
#  module_wrapper_8 (ModuleWr  (None, 512)               26214912
#  apper)
#
#  module_wrapper_9 (ModuleWr  (None, 512)               0
#  apper)
#
#  module_wrapper_10 (ModuleW  (None, 512)               0
#  rapper)
#
#  module_wrapper_11 (ModuleW  (None, 1)                 513
#  rapper)
#
#  module_wrapper_12 (ModuleW  (None, 1)                 0
#  rapper)
#
# =================================================================
# Total params: 26318689 (100.40 MB)
# Trainable params: 26318305 (100.40 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
your_optimser = 'adam'
loss_function = "binary_crossentropy"
model.compile(optimizer=your_optimser,
              loss=loss_function,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrap  (None, 178, 178, 32)      896
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 176, 176, 32)      9248
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 88, 88, 32)        0
#  apper)
#
#  module_wrapper_3 (ModuleWr  (None, 86, 86, 64)        18496
#  apper)
#
#  batch_normalization (Batch  (None, 86, 86, 64)        256
#  Normalization)
#
#  module_wrapper_4 (ModuleWr  (None, 43, 43, 64)        0
#  apper)
#
#  module_wrapper_5 (ModuleWr  (None, 41, 41, 128)       73856
#  apper)
#
#  batch_normalization_1 (Bat  (None, 41, 41, 128)       512
#  chNormalization)
#
#  module_wrapper_6 (ModuleWr  (None, 20, 20, 128)       0
#  apper)
#
#  module_wrapper_7 (ModuleWr  (None, 51200)             0
#  apper)
#
#  module_wrapper_8 (ModuleWr  (None, 512)               26214912
#  apper)
#
#  module_wrapper_9 (ModuleWr  (None, 512)               0
#  apper)
#
#  module_wrapper_10 (ModuleW  (None, 512)               0
#  rapper)
#
#  module_wrapper_11 (ModuleW  (None, 1)                 513
#  rapper)
#
#  module_wrapper_12 (ModuleW  (None, 1)                 0
#  rapper)
#
# =================================================================
# Total params: 26318689 (100.40 MB)
# Trainable params: 26318305 (100.40 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
batch_size = 32

history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 596s 7s/step - loss: -90499.4766 - accuracy: 0.1914 - val_loss: -90685.8672 - val_accuracy: 0.1822
# Epoch 2/20
# 58/58 [==============================] - 298s 5s/step - loss: -901510.3750 - accuracy: 0.1936 - val_loss: -863079.3125 - val_accuracy: 0.1822
# Epoch 3/20
# 58/58 [==============================] - 307s 5s/step - loss: -3183961.2500 - accuracy: 0.1936 - val_loss: -3945430.2500 - val_accuracy: 0.1822
# Epoch 4/20
# 58/58 [==============================] - 299s 5s/step - loss: -7782907.0000 - accuracy: 0.1936 - val_loss: -8630643.0000 - val_accuracy: 0.1822
# Epoch 5/20
# 58/58 [==============================] - 309s 5s/step - loss: -15318559.0000 - accuracy: 0.1936 - val_loss: -18557954.0000 - val_accuracy: 0.1822
# Epoch 6/20
# 58/58 [==============================] - 290s 5s/step - loss: -26775070.0000 - accuracy: 0.1936 - val_loss: -34755264.0000 - val_accuracy: 0.1822
# Epoch 7/20
# 58/58 [==============================] - 292s 5s/step - loss: -43156036.0000 - accuracy: 0.1936 - val_loss: -49944228.0000 - val_accuracy: 0.1822
# Epoch 8/20
# 58/58 [==============================] - 297s 5s/step - loss: -64056904.0000 - accuracy: 0.1936 - val_loss: -59140384.0000 - val_accuracy: 0.1822
# Epoch 9/20
# 58/58 [==============================] - 292s 5s/step - loss: -91185632.0000 - accuracy: 0.1936 - val_loss: -89074128.0000 - val_accuracy: 0.1822
# Epoch 10/20
# 58/58 [==============================] - 294s 5s/step - loss: -124950008.0000 - accuracy: 0.1936 - val_loss: -109126128.0000 - val_accuracy: 0.1822
# Epoch 11/20
# 58/58 [==============================] - 298s 5s/step - loss: -165779296.0000 - accuracy: 0.1936 - val_loss: -157769200.0000 - val_accuracy: 0.1822
# Epoch 12/20
# 58/58 [==============================] - 292s 5s/step - loss: -211625952.0000 - accuracy: 0.1936 - val_loss: -250272240.0000 - val_accuracy: 0.1822
# Epoch 13/20
# 58/58 [==============================] - 300s 5s/step - loss: -267122448.0000 - accuracy: 0.1936 - val_loss: -315268288.0000 - val_accuracy: 0.1822
# Epoch 14/20
# 58/58 [==============================] - 295s 5s/step - loss: -333918208.0000 - accuracy: 0.1936 - val_loss: -271937024.0000 - val_accuracy: 0.1822
# Epoch 15/20
# 58/58 [==============================] - 297s 5s/step - loss: -408059008.0000 - accuracy: 0.1936 - val_loss: -424720096.0000 - val_accuracy: 0.1822
# Epoch 16/20
# 58/58 [==============================] - 297s 5s/step - loss: -489922848.0000 - accuracy: 0.1936 - val_loss: -461236896.0000 - val_accuracy: 0.1822
# Epoch 17/20
# 58/58 [==============================] - 295s 5s/step - loss: -582740800.0000 - accuracy: 0.1936 - val_loss: -693481792.0000 - val_accuracy: 0.1822
# Epoch 18/20
# 58/58 [==============================] - 295s 5s/step - loss: -684169856.0000 - accuracy: 0.1936 - val_loss: -778643328.0000 - val_accuracy: 0.1822
# Epoch 19/20
# 58/58 [==============================] - 294s 5s/step - loss: -795949376.0000 - accuracy: 0.1936 - val_loss: -685120960.0000 - val_accuracy: 0.1822
# Epoch 20/20
# 58/58 [==============================] - 295s 5s/step - loss: -922016768.0000 - accuracy: 0.1936 - val_loss: -762099904.0000 - val_accuracy: 0.1822

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)


# Thus we can clearly that model Overfit and we need to chose right data augumentation strategy
# Out:
# 58/58 [==============================] - 71s 1s/step - loss: -751088064.0000 - accuracy: 0.1936
# 15/15 [==============================] - 28s 2s/step - loss: -762099904.0000 - accuracy: 0.1822
# Accuracy:  0.1936008632183075
# Validation Accuracy:  0.18221257627010345
# Loss:  -751088064.0
# Validation Loss -762099904.0

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

#image_class = ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train,
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test,
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 891 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
# visualize how your augmentation strategy works for one instance of training image.
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
input_shape
# Out:
# (180, 180, 3)

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
## You can use Dropout layer if there is an evidence of overfitting in your findings
# input_shape = (180,180,3)
# Define the model architecture
tf.config.run_functions_eagerly(True)
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

# Build the model
model.build((None, *input_shape))

# Print model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  module_wrapper_43 (ModuleW  multiple                  896
#  rapper)
#
#  module_wrapper_44 (ModuleW  multiple                  9248
#  rapper)
#
#  module_wrapper_45 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_46 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_47 (ModuleW  multiple                  18496
#  rapper)
#
#  module_wrapper_48 (ModuleW  multiple                  36928
#  rapper)
#
#  module_wrapper_49 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_50 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_51 (ModuleW  multiple                  73856
#  rapper)
#
#  module_wrapper_52 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_53 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_54 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_55 (ModuleW  multiple                  28901888
#  rapper)
#
#  module_wrapper_56 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_57 (ModuleW  multiple                  4617
#  rapper)
#
# =================================================================
# Total params: 29045929 (110.80 MB)
# Trainable params: 29045929 (110.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 20
batch_size = 32

history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)

# %%
##after changes

lr_schedule = ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=100000,
    decay_rate=0.9)
optimizer = Adam(learning_rate=lr_schedule,  beta_1=0.9, beta_2=0.999,epsilon=None, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
    patience=3,
    verbose=1,
    factor=0.5,
    min_lr=0.00001)
learning_rate_reduction

# %% [markdown]
# ### Training the model

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
epochs = 20
batch_size = 10

history = model.fit(train_batches, epochs=epochs, verbose=1,  validation_data=valid_batches, callbacks=[learning_rate_reduction])

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
import matplotlib.pyplot as plt
data = dict()

for i in class_names:
  data[i] = []

plt.figure(figsize=(10, 10))
for images, labels in train_ds:
  for i in range(9):
    data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in data:
  data[i] = len(data[i])

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
# ### **Actinic Keratosos** and **Seborrheic keratosis**
#
# #### - Which classes dominate the data in terms proportionate number of samples?
#
# **Pigmented benign keratosis** dominates the data of count more than 100 in training

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7933EC65AE60>: 100%|██████████| 500/500 [00:29<00:00, 16.88 Samples/s]
# Initialised with 441 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7933EC68F5B0>: 100%|██████████| 500/500 [00:32<00:00, 15.21 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7933EC969ED0>: 100%|██████████| 500/500 [00:28<00:00, 17.76 Samples/s]
# Initialised with 439 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7933EC96A9E0>: 100%|██████████| 500/500 [01:48<00:00,  4.63 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2530x2122 at 0x79340C5C47F0>: 100%|██████████| 500/500 [01:39<00:00,  5.04 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7933ECA32B00>: 100%|██████████| 500/500 [00:24<00:00, 20.32 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7933ECACAD40>: 100%|██████████| 500/500 [00:49<00:00, 10.14 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x79340C4B35B0>: 100%|██████████| 500/500 [00:24<00:00, 20.60 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79340C5E6B90>: 100%|██████████| 500/500 [00:25<00:00, 19.76 Samples/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028393.jpg_83750e80-a650-4fd5-9fc8-fee16096be16.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_96eb5163-1340-421e-9da3-2fece15445e8.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_1ea449d9-9939-449d-bbe3-07ef8bac052c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_cef5971f-2ee5-446a-b875-a3ae72f9dc35.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025953.jpg_029cbb03-30fa-464d-abf0-bdf3a8d14d11.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_e9134cdb-5482-4dd3-be1b-0df2900dabf9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_88b7518f-7540-40c2-9b6f-bf857e4ca0e9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031335.jpg_fda85fca-2d66-43e0-ba47-c5eb9e1dfec4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_63589ed6-f606-4a3a-aa29-3138041e9d65.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027958.jpg_36c843ef-320f-44b1-98a1-3975e1e3da3f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026457.jpg_ba0587b8-8c80-478a-b4b2-a6a3693b0d46.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_f25a169a-5898-4298-8a82-74c8bbac55fc.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_fa124bb0-112e-47cd-b9be-05fd7edf58d7.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031228.jpg_ed6762ce-fad4-44fe-a122-12d2e6a1b187.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_1986cbfe-bc7f-4888-939a-3fb30023e447.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030655.jpg_d41b64cf-f05f-49b2-ab78-e55dc7405e38.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_46b08665-ee47-494b-8a4d-26bcd56855ef.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031922.jpg_2043335a-ec14-441f-a4ba-7b400ae3a4ff.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028854.jpg_642e1a01-2988-4299-9468-ad05e856d8fb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_f06dbd5c-24ec-48a9-b488-e883bfa95857.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027447.jpg_6185a153-44e8-444d-acba-250b47b754ba.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029210.jpg_b84ee431-fa5c-4083-bcee-93eb2e03c757.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026650.jpg_e2e6945c-3344-4f77-ae97-a0d77fcb90a0.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_7c40f551-e8e2-4296-9400-fd01334c271c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_a0e71020-d04f-4310-b400-9eeafe9ab419.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027958.jpg_529193b4-a5e7-4739-a1bc-38198052c288.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028393.jpg_319d2ab9-29d2-46a1-ba85-1ba20b78bc3b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026848.jpg_41956c53-283d-41ab-92a2-73c6f3eecde8.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029840.jpg_489cde72-f457-429a-92cd-5a28f935dcb2.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_837e51b3-229d-45e9-8ff6-bf2c961f18a9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_64d682f5-2627-47cf-816c-171f02b12580.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_5245b0e1-bea3-4cd8-86b4-fbac34e72108.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_91b46943-a79a-4851-b453-27e494d46ad4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028370.jpg_b62c5ff4-e685-4125-adfb-a3e025a1cd4a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026468.jpg_477a344f-fec8-4ae3-a6a6-b4a2c65776ec.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027580.jpg_f0768858-936d-4aaa-a1f2-c456f33d09d7.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_9137bc5e-790d-4bec-a435-5e7790b2e06e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025803.jpg_f9375ecc-9a4c-4306-897f-a0ef6613e814.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031040.jpg_7b0cf832-75d4-4dbb-96f5-68f357646731.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033494.jpg_7e913622-7c42-4902-89e9-98035d59553b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028854.jpg_949cbb2a-a2ca-4196-8ef8-d6e7dee99782.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029460.jpg_6a799429-3100-494d-8a19-172e934f8157.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025803.jpg_e7540da3-0862-4757-8c4c-4b4a3343880e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033358.jpg_1c90285a-c658-4c18-b769-d345f6fe8ad0.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030242.jpg_fab36075-bff0-4521-b78f-998407a99e88.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_6a02326d-9b72-464b-8f50-bc7c8ceec7a5.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033413.jpg_c37131e6-9ca6-4728-bf75-24372ab870df.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029659.jpg_b139cbba-dfc2-439a-b217-3d9e14ddc0cb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028517.jpg_2e028e2a-655b-4dd0-ad18-cb838e760122.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_f861a287-1496-434c-8dff-1e5667607dff.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_4f097d58-8b00-4918-9c13-80c69df316e9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_138ce0a7-4310-4eec-a86b-43b3346e9e88.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028558.jpg_b25d3ebb-b993-4d07-9d31-9fcb73dafc4c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032404.jpg_7fb0c3d6-b027-4b93-8f4e-2089508cf13a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029915.jpg_424dfee1-cac2-462c-80f9-154f7e48ea66.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027884.jpg_63702108-42d0-46d4-a7e8-f5480c2bc9a9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_aa4c13a6-c532-4aeb-a3c0-9b32863df498.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026984.jpg_0209ad3e-7805-4569-a1fe-bd18b62d6d62.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027562.jpg_300bc85f-3909-42da-be39-5785e0d2220b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031381.jpg_b3baad8e-5f11-452e-96da-544a9b4437f6.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_da9358e2-a176-422c-ae87-34631996cccb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_2d487453-c93b-4dca-8b69-42bfc0f346c5.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033413.jpg_56e2a28b-0061-46c1-9002-1bda8b32fa3c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_058145c7-c407-4edd-86a6-11f71539e524.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031040.jpg_c324609f-b98a-46ff-88cd-a7864fcbe29a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027896.jpg_e1d498e8-8dd9-417d-92d7-dccf43a982a2.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026625.jpg_52e045e8-4da3-4ce7-9ab2-ace6504a8bec.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_7f7feade-e045-4197-b89e-e0039175b431.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_22eac288-75e1-469a-9b1b-ad97e6a5aeab.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_44dedebb-e5ed-49b2-af7f-038780428891.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033358.jpg_020f72ed-b8c4-4059-bb18-d0e0cb3e9220.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026212.jpg_c69a57f8-e5c8-4f56-835c-068a710e5e30.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027650.jpg_4376ae26-e39d-420b-b322-7d74125b1cfb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_d3979a94-d42f-455a-9595-17b983315499.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_d11130b9-4386-4f0e-96f7-e31949c214a3.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_f9e52413-9304-44b9-bfd1-78c1976c53a4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_92f746d4-b92e-4361-b082-189469d852bb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_53993347-8799-4250-b04a-f7909ad04849.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026525.jpg_2c6d39e8-7c1c-4d19-8f10-d30c6216cdc0.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_3d667261-24e5-4341-9b18-33afce22e761.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_e0e0a2d3-0d00-49db-86ea-15a827fd045d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027254.jpg_fc64d420-6630-410a-85bf-3527179c96bc.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033413.jpg_d961bd54-312b-4ac8-b76c-46109bb31d03.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031609.jpg_0542f94b-28bd-4a20-97c2-de7b73dd2712.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027950.jpg_07353854-0c89-40ef-8930-247c7c2b4621.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030036.jpg_4f6d1999-4778-4f2a-b97c-93b85d96db1a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_4a4b213d-783d-4d34-8047-237e49d0e7e8.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033494.jpg_dd8e8ba5-6195-464c-a6d0-85031c860cbe.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_98a4ae95-8f95-4561-971c-1cf29455da50.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033413.jpg_55cff61b-fa68-4bde-aaa2-41030737ebad.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027950.jpg_bae458e1-e342-433e-af50-dc1e1670ac98.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027452.jpg_d60fa645-ba94-4a72-9232-22e44f8a62fb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031381.jpg_0790967a-9187-46d6-956d-56296ab5e38e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_636b916a-a3c2-4f33-87a1-eefd0b12f16c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026857.jpg_6ce0241c-bb57-4551-9af3-a0f3d3676b7d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030242.jpg_3caddabc-b842-4abe-9cef-a176825a9427.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_8e7bf98f-301a-4c16-8e2f-4642a7c8dda3.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028063.jpg_b646b51e-9ead-4965-947d-d5b0ff430e24.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031040.jpg_c0552747-3851-40d9-8ed2-cc612d580554.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030143.jpg_9ac36cf4-0268-44f5-98f1-a8852237b7ed.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_8d81cf34-462d-4643-bef7-ddb3ac7e3155.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025957.jpg_5b41ca3c-469b-4323-a6c7-cd326015cda1.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031228.jpg_c008955b-98f5-41a8-9559-571990062d6d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033358.jpg_f00d63f6-6e2c-491e-bdc7-fdd11af9dae9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_a574827b-3571-4002-96ed-01adce696e87.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_386a8f9f-f746-4c46-9205-9d84fc076f4f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032854.jpg_8547916c-7f8e-487e-8f27-a06f63935efd.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032854.jpg_73faae9b-fc41-4b4e-85b9-7df49b1bc2de.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_5e9f364e-7143-4037-a624-bad5d5674f66.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_59d96471-d879-4d01-a059-b403fea9f84f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_f040107a-807e-4281-82a7-bf30579bb453.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030463.jpg_25b074f4-a3ca-4303-9c57-795baee7494f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026149.jpg_3c00581b-1700-438b-b37b-95be9f7d44ee.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032206.jpg_003deba0-6cd9-4edc-9ddf-0e50cb58c620.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030463.jpg_b7779bd0-38f3-4448-b316-13d0928edb88.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028076.jpg_2c6c7220-7843-4e8f-9778-c04aa84d2723.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_89201a90-35be-48a3-aca4-c60589606909.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027172.jpg_f83d50e3-5232-427a-8c17-fd82e87c7667.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031040.jpg_e6e59000-e9bf-4c2d-a207-4ec896ca7162.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026905.jpg_ee20d325-c343-4800-86b7-008c936b6f1f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031381.jpg_4abaaa4a-d659-4ab2-8409-f36cb2544b27.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_8dd05df4-17f8-4d7b-a87b-3d3e1f2f256c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029840.jpg_c187fe34-064a-4a11-a927-71b62f7f4ffa.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029713.jpg_f61b420a-f7d6-44f6-9e87-a4e8cfdd0e80.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_c341884e-6983-4f99-9854-cc6c3c432428.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029025.jpg_3de73b7c-710b-48f5-99bd-914537490986.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026468.jpg_1eae3213-34cb-4a20-b8cd-cf96b5a3b390.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_3d231165-9fff-43ea-8324-1200024fde16.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033494.jpg_fedaaa1c-cb86-4970-8e31-4aa41abed8c5.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025825.jpg_6284f742-53ec-471a-b514-b88bdf6e5b32.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032422.jpg_18da1658-75e1-4b68-9bd1-b771dda226dd.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029141.jpg_6a39d4b6-fad4-47ee-b1c0-f310afe27a1c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_f62e6c33-232d-498f-a43f-3864c5b2ddea.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028370.jpg_41accc4e-161d-44fc-bd5b-5abc1bd7600c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027950.jpg_c4d76634-4803-44f2-9706-daf41104a654.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028393.jpg_1dff7cd5-220f-488a-b811-e6781ee42d64.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033866.jpg_c173756d-bd53-41dc-90f3-28461a083254.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026194.jpg_a6912b8d-244e-4740-af88-64e66127d032.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_d4b57a06-20e5-4f0d-8817-09cf3a9e46ee.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030825.jpg_26d1724b-5403-434e-9d4e-8c03b734ba17.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026468.jpg_73097d3f-7244-4c89-97b3-75f9d399841d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033413.jpg_430e9f03-3bfa-4b8f-bba4-38e891d37d2b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026575.jpg_c0072fe4-92ea-41d6-9827-6b29b85bb809.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027650.jpg_6485f5d7-2fa4-4920-af5d-4810442ab0a4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027536.jpg_be5dcb89-93cc-488e-9d2d-e202401dafbb.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029133.jpg_604c48c1-0c2f-4212-bbdb-46f05582b319.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028990.jpg_a4096bff-8449-4ebe-9547-86b6b5adf11a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031609.jpg_fd5bb1b5-ad28-415e-a887-62bcbf637091.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033151.jpg_57f1bed0-420c-4699-b6d9-4dfec265122d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027668.jpg_59bcabb6-c3ab-4a26-9d2f-0e60faa5f140.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033866.jpg_4655573e-6844-4e7e-ab7c-76167c684995.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030142.jpg_09be48b9-7128-4339-9170-5b1d830ce067.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_20310515-c14b-4de5-808c-59924eb708a5.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_86fe9569-160a-4be2-988f-da1ad2f7fb66.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028190.jpg_7449c4c0-0875-4043-83ef-a13d30792c39.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031922.jpg_a9f2056f-5440-46d9-8350-561d16ae3926.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030655.jpg_9306a637-5a3f-4b38-ab17-e11dd20a9062.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_b83c85b0-bc52-43ae-a2ef-3191b1314655.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_43be295e-22cc-4976-8d1b-0e71f15aa7c7.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033811.jpg_8043315f-79b1-416f-9b61-dbc87bffd3d3.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026625.jpg_67f1702b-1f5e-4aef-b3e7-05599047dfbe.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030408.jpg_ba00ef5b-034f-454e-a2f2-533e90b85da3.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031108.jpg_806afa31-e164-43df-af90-68ccf01ec311.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_10b27dce-785c-4eb1-9077-482768a1464e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027580.jpg_4daf708b-9f2f-4992-a239-a75196f183ba.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030730.jpg_60ee28fb-8bd4-4838-a019-b2ebf8460a43.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_3fdac0f7-d255-4419-95a4-881189007fc7.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031823.jpg_cb533f5d-3239-4cb0-b49b-3072a4931133.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030408.jpg_e4305bc9-06f6-4da2-a440-1a28ab052a3b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_edce7d1b-7541-45f9-8762-7ae79837a962.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026468.jpg_cd54738f-2c0a-4f60-b1c1-024e4454c932.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027896.jpg_adcc902b-c219-4d38-8942-bd383400433a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_65fd25be-7c2a-4a2d-840f-b67fb2253abc.jpg',
# ...
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026473.jpg_efc8fc36-ae44-4644-8da6-efa54b48141b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025911.jpg_1c5bb66a-5e3f-4cbc-b6a5-025053f1f2ed.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030757.jpg_65c3d4eb-f584-4d4b-8b30-56587933a07a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_aadabbca-fdcf-40d6-9764-0536886a0aec.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033626.jpg_66ccccbf-44f0-44e7-8edf-02b7f24237e4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026789.jpg_091926d0-5ffa-4cc0-a0e1-e14f0a33ece6.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030665.jpg_c058ee38-278f-4b5f-be36-317983994f40.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033810.jpg_946cbf03-efa1-4df5-9052-517a9ab236c6.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030021.jpg_4129c8e5-06d8-4e35-a867-944cddb22ab3.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025954.jpg_a6c9649a-8fef-4a37-a684-e8d2ed39851d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029248.jpg_a7af461a-2d2d-4647-b8cf-d061480d495d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029962.jpg_dd1cf24d-8923-44fe-8461-40ed05f6d31a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033808.jpg_f77657ac-dff9-40a8-af88-05024a2309c6.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027107.jpg_af41a590-35e6-4b2e-96cb-1fc7941e814e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030442.jpg_50cbc44e-620c-4b9d-ab07-1a6f23240f1a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032941.jpg_e81ea076-4aad-4186-ae8d-ebd766aad004.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027876.jpg_8ecae0e7-ee18-4992-a7fb-162c579eaf3f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030665.jpg_10e4b472-a26e-4330-a956-8bc6e17d9fd8.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027598.jpg_18b2902d-d3b3-4ac3-8c60-0c3582e9a74d.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029962.jpg_01c9f36c-90f4-4d94-9536-469cd58d5d80.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030442.jpg_13d27ab2-2e05-45e9-8a6f-6cc56870f6bc.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029130.jpg_51b0afcf-59db-44ba-b4c7-84b58ae0dace.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032642.jpg_5b85ec48-86b9-4915-b5d4-00b78417e3d8.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025302.jpg_1e32cb4d-8fae-4c0f-8239-a23bce14f4f3.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028880.jpg_f471ba4a-38f8-4efa-9d97-d1267006ec12.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031429.jpg_d4b74afe-e2f0-4bb1-8e4a-f4e44034d4e4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025504.jpg_7b3228fc-a691-4c10-9ef0-e86fbb04c9e6.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030011.jpg_38606c1b-04cc-4536-950c-df340fbb3d57.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025771.jpg_e833cb65-e499-476b-b08f-899f996e174b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029297.jpg_43e6fcab-f246-42f6-b6ce-29acefd75eb6.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031344.jpg_a771ab95-d370-4c0d-8ecb-cf1c72d1d685.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033891.jpg_e143f4a2-0c29-4b41-a36d-5a3b7fd4e591.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031735.jpg_b0a468dd-1f4e-4767-8eb0-8c251966eefd.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031344.jpg_a30275ec-0dcc-4b8b-9f6b-bb244d9248d7.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031271.jpg_e677eac4-1f8a-4d44-b232-ea3f8d123437.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027044.jpg_39aba156-616b-43e5-90d8-c790e09de655.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031827.jpg_e68ac581-3a8e-4cd1-8e58-7c02f2d80e0b.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029039.jpg_cea52511-097e-43fd-8fd9-d441df8e8f30.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028735.jpg_1e426d9a-b8dd-46eb-87fa-cd57f227698e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027107.jpg_d1b8c061-ba76-44a8-8275-8602bdd7736a.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033810.jpg_c9bd6963-1d39-4f45-a7e5-cfbfb5ae95c4.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032642.jpg_84407b1e-0125-4cee-b02e-4ce17073140c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029973.jpg_ba830157-2398-4c7b-864a-8c1d32321ec1.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033810.jpg_0b173001-6b6b-4469-b770-d65af39a00a9.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031429.jpg_2689014c-58c0-4898-b454-c4580f6b871c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033810.jpg_4ab0253c-4164-4a04-bd19-687ccccc4a62.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031457.jpg_5abb66da-a711-4ebe-a1b0-e140447b2229.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025668.jpg_0859db1c-6f45-4dad-b9cd-a30ffd382058.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025903.jpg_42b08333-07c1-428d-848f-880c4ec9860e.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033847.jpg_7cc71373-6f1a-482e-ad30-e802868d7fed.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027648.jpg_791e08fa-928b-4da9-8a00-dee8840b6d84.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033626.jpg_e0cd09b0-f595-4bc7-97ac-afe737ec7a14.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025302.jpg_3cdc645d-4dc8-493c-bcdc-d5771eef0904.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032642.jpg_5f3a33ac-cc88-47de-91f3-1e7c21d4f90c.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029578.jpg_774fad87-0389-4606-83cb-506490e2f120.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030579.jpg_410fc357-b42e-41e1-a110-953bc0b0fadc.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027488.jpg_ad3c2a39-17c6-4ebb-aace-ffa146676b4f.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025302.jpg_bc6b2e28-781d-452b-afac-62d3c27ea375.jpg',
#  '/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_61efdaed-5672-47eb-a2f0-43b76bd6eeaf.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# Label
# actinic keratosis             500
# dermatofibroma                500
# basal cell carcinoma          500
# melanoma                      500
# nevus                         500
# pigmented benign keratosis    500
# seborrheic keratosis          500
# squamous cell carcinoma       500
# vascular lesion               500
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="/content/drive/MyDrive/Upgrad AIML PGDA Notes/26.Convolutional Neural Networks/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6805 files belonging to 9 classes.
# Using 5444 files for training.
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
   subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6805 files belonging to 9 classes.
# Using 1361 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))
model.build((None, *input_shape))
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/normalization/batch_normalization.py:883: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  module_wrapper_73 (ModuleW  multiple                  896
#  rapper)
#
#  module_wrapper_74 (ModuleW  multiple                  9248
#  rapper)
#
#  module_wrapper_75 (ModuleW  multiple                  0
#  rapper)
#
#  batch_normalization_6 (Bat  multiple                  128
#  chNormalization)
#
#  module_wrapper_76 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_77 (ModuleW  multiple                  18496
#  rapper)
#
#  module_wrapper_78 (ModuleW  multiple                  36928
#  rapper)
#
#  module_wrapper_79 (ModuleW  multiple                  0
#  rapper)
#
#  batch_normalization_7 (Bat  multiple                  256
#  chNormalization)
#
#  module_wrapper_80 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_81 (ModuleW  multiple                  73856
#  rapper)
#
#  batch_normalization_8 (Bat  multiple                  512
#  chNormalization)
#
#  module_wrapper_82 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_83 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_84 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_85 (ModuleW  multiple                  7225472
#  rapper)
#
#  batch_normalization_9 (Bat  multiple                  512
#  chNormalization)
#
#  module_wrapper_86 (ModuleW  multiple                  0
#  rapper)
#
#  module_wrapper_87 (ModuleW  multiple                  129
#  rapper)
#
# =================================================================
# Total params: 7366433 (28.10 MB)
# Trainable params: 7365729 (28.10 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
lr_schedule = ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=0,
    decay_rate=0.0)
optimizer = Adam(learning_rate=lr_schedule,  beta_1=0.9, beta_2=0.999,epsilon=None, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
# epochs = 30
## Your code goes here, use 50 epochs.

epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
    patience=3,
    verbose=1,
    factor=0.5,
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds, epochs = epochs, validation_data=val_ds )

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# * The implementation of class rebalancing effectively mitigated overfitting issues, consequently leading to a decrease in loss. However, this improvement came at the cost of a notable reduction in accuracy.
#
# * Initially, the absence of ImageDataGenerator resulted in significant data overfitting.
#
# * The subsequent inclusion of dropout and ImageDataGenerator techniques successfully alleviated overfitting concerns.
#
# * Finally, the utilization of Batch Normalization and Augmentation strategies significantly contributed to ongoing improvements in the model's performance.
